# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

page =requests.get("https://weather.com/weather/tenday/l/San+Francisco+CA?canonicalCityId=dfdaba8cbe3a4d12a8796e1f7b1ccc7174b4b0a2d5ddb1c8566ae9f154fa638c")
# Print the status code of the response
soup =BeautifulSoup(page.content, 'html.parser')

html = list(soup.children)[1]
body = list(html.children)[1]

weather = {}

day_list = []
date_list = []
high_temp_list = []
low_temp_list = []
weather_condition = []
precipation = []
wind_speed = []
weather_report = []

#data = body.find_all('details', class_="Disclosure--themeList--uBa5q",index = '0')

summary = body.find_all('p',class_ = 'DailyContent--narrative--3AcXd')
for j in range(1,11):
    description = list(summary)[j].text
    weather_report.append(description)

for i in range(1,11):
    data = body.find('div', id = f'detailIndex{i}')

    first_value = list(data.children)[0].get_text() + '.12.2020'
    day_and_date = first_value.split()

    day_list.append(day_and_date[0])
    date_list.append(day_and_date[1])

    second_value = list(data.children)[1].get_text()

    high_and_low_temp = second_value.replace('/',' ').replace('°','')
    temperature = high_and_low_temp.split()

    high_temp = temperature[0] 
    high_temperature = int((int(high_temp)-32)*(5/9))
    high_temp_list.append(str(high_temperature) + '°C')

    low_temp = temperature[1]
    low_temperature = int((int(low_temp)-32)*(5/9))
    low_temp_list.append(str(low_temperature) + '°C')

    third_value = list(data.children)[2].get_text()
    weather_condition.append(third_value)

    fourth_value = list(data.children)[3].get_text()
    precipation.append(fourth_value)

    fifth_value = list(data.children)[4].get_text()
    wind_speed.append(fifth_value)


weather['Day_name'] = day_list
weather['Date'] = date_list
weather['Max Temperature'] = high_temp_list
weather['Min Temperature'] = low_temp_list
weather['Speed of wind']= wind_speed
weather['Weather alert'] = weather_report

Dataset = pd.DataFrame(weather)
Dataset
# Out:
#   Day_name        Date Max Temperature Min Temperature Speed of wind  \
# 0      Fri  11.12.2020            12°C             8°C    WNW 11 mph
# 1      Sat  12.12.2020            13°C             9°C     SW 11 mph
# 2      Sun  13.12.2020            14°C             8°C    SSW 16 mph
# 3      Mon  14.12.2020            13°C             6°C     WNW 8 mph
# 4      Tue  15.12.2020            13°C             8°C     SSW 7 mph
# 5      Wed  16.12.2020            14°C             7°C    SSW 11 mph
# 6      Thu  17.12.2020            14°C             7°C      NW 8 mph
# 7      Fri  18.12.2020            14°C             7°C     WNW 7 mph
# 8      Sat  19.12.2020            15°C             6°C      NW 9 mph
# 9      Sun  20.12.2020            15°C             6°C    WNW 11 mph
#
#                                        Weather alert
# 0  Partly cloudy skies this evening will become o...
# 1  Partly cloudy skies during the morning hours w...
# 2  Cloudy with periods of light rain. Low 48F. Wi...
# 3  Cloudy with showers. High 56F. Winds SW at 10 ...
# 4  Cloudy with occasional showers late at night. ...
# 5  Steady light rain in the morning. Showers cont...
# 6  Showers in the evening, then cloudy overnight....
# 7  Sunshine and clouds mixed. High 57F. Winds WNW...
# 8  Partly cloudy skies during the evening will gi...
# 9  Partly to mostly cloudy. High 57F. Winds SSW a...

# %%
#summary is not included

import requests
from bs4 import BeautifulSoup
import pandas as pd

page =requests.get("https://weather.com/weather/tenday/l/San+Francisco+CA?canonicalCityId=dfdaba8cbe3a4d12a8796e1f7b1ccc7174b4b0a2d5ddb1c8566ae9f154fa638c")
# Print the status code of the response
print(page)
soup =BeautifulSoup(page.content, 'html.parser')

html = list(soup.children)[1]
body = list(html.children)[1]

weather = {}

day_list = []
date_list = []
high_temp_list = []
low_temp_list = []
weather_condition = []
precipation = []
wind_speed = []

#data = body.find_all('details', class_="Disclosure--themeList--uBa5q",index = '0')
for i in range(1,11):
    data = body.find('div', id = f'detailIndex{i}')

    first_value = list(data.children)[0].get_text() + '.12.2020'
    day_and_date = first_value.split()

    day_list.append(day_and_date[0])
    date_list.append(day_and_date[1])

    second_value = list(data.children)[1].get_text()

    high_and_low_temp = second_value.replace('/',' ')
    temperature = high_and_low_temp.split()

    high_temp = temperature[0] 
    high_temp_list.append(high_temp)

    low_temp = temperature[1]
    low_temp_list.append(low_temp)

    third_value = list(data.children)[2].get_text()
    weather_condition.append(third_value)

    fourth_value = list(data.children)[3].get_text()
    precipation.append(fourth_value)

    fifth_value = list(data.children)[4].get_text()
    wind_speed.append(fifth_value)

weather['Day_name'] = day_list
weather['Date'] = date_list
weather['Max Temperature'] = high_temp_list
weather['Min Temperature'] = low_temp_list
weather['Speed of wind']= wind_speed

Dataset = pd.DataFrame(weather, index = weather['Date'])
Dataset
# Out:
# <Response [200]>
#            Day_name        Date Max Temperature Min Temperature Speed of wind
# 10.12.2020      Thu  10.12.2020             57°             43°      W 16 mph
# 11.12.2020      Fri  11.12.2020             55°             47°    WNW 11 mph
# 12.12.2020      Sat  12.12.2020             57°             49°     SW 12 mph
# 13.12.2020      Sun  13.12.2020             58°             48°    SSW 17 mph
# 14.12.2020      Mon  14.12.2020             57°             44°     WNW 9 mph
# 15.12.2020      Tue  15.12.2020             56°             46°     WSW 8 mph
# 16.12.2020      Wed  16.12.2020             57°             46°     WSW 8 mph
# 17.12.2020      Thu  17.12.2020             58°             45°      NW 7 mph
# 18.12.2020      Fri  18.12.2020             58°             46°      NE 8 mph
# 19.12.2020      Sat  19.12.2020             59°             44°      NW 9 mph
